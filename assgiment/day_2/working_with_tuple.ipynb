# %%
data = (10, 20, 30, 20, 40)

print(data.count(20))
# Out:
# 2

# %%
data = (10, 20, 30, 20, 40)

print(data.index(30))
# Out:
# 2

# %%
data = (10, 20, 30, 20, 40)

print(data.count(10))
# Out:
# 1

# %%
data = (10, 20, 30, 20, 40)

print(data.index(40))
# Out:
# 4

# %%
data = (10, 20, 30, 20, 40)

data[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 data = (10, 20, 30, 20, 40)
#       2
# ----> 3 data[0] = 100
#
# TypeError: 'tuple' object does not support item assignment
