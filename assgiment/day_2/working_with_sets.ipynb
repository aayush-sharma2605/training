# %%
menu_A = {"Pizza", "Burger", "Pasta", "Sandwich", "Coffee"}
menu_B = {"Burger", "Momos", "Pasta", "Tea", "Ice Cream"}

print(menu_A.union(menu_B))

# %%
menu_A = {"Pizza", "Burger", "Pasta", "Sandwich", "Coffee"}
menu_B = {"Burger", "Momos", "Pasta", "Tea", "Ice Cream"}

print(menu_A.intersection(menu_B))

# %%
menu_A = {"Pizza", "Burger", "Pasta", "Sandwich", "Coffee"}
menu_B = {"Burger", "Momos", "Pasta", "Tea", "Ice Cream"}

print(menu_A.difference(menu_B))

# %%
menu_A = {"Pizza", "Burger", "Pasta", "Sandwich", "Coffee"}
menu_B = {"Burger", "Momos", "Pasta", "Tea", "Ice Cream"}

print(menu_B.difference(menu_A))

# %%
menu_A = {"Pizza", "Burger", "Pasta", "Sandwich", "Coffee"}
menu_B = {"Burger", "Momos", "Pasta", "Tea", "Ice Cream"}

final_menu = menu_A | menu_B

print(final_menu)
